# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete_df = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
total_schools = len(school_data_complete_df["school_name"].unique())
total_students = school_data_complete_df["student_name"].count()
total_budget = school_data_complete_df["budget"].unique().sum()
#total_budget = school_data["budget"].sum()
avg_math_score = school_data_complete_df["math_score"].mean()
avg_reading_score = school_data_complete_df["reading_score"].mean()
percent_passed_math = ((school_data_complete_df.loc[school_data_complete_df["math_score"] >= 70, "math_score"]).count()/total_students)*100
percent_passed_reading = ((school_data_complete_df.loc[school_data_complete_df["reading_score"] >= 70, "reading_score"]).count()/total_students)*100           
first_passed_math = school_data_complete_df.loc[school_data_complete_df["math_score"] >= 70, ["reading_score"]]
then_passed_reading = (first_passed_math.loc[first_passed_math["reading_score"] >= 70, "reading_score"]).count()
percent_overall_passed = (then_passed_reading/total_students)*100          

district_summary_df = pd.DataFrame({"Total Schools": [total_schools],
                                    "Total Students": [total_students],
                                    "Total Budget": [total_budget],
                                    "Average Math Score": [avg_math_score],
                                    "Average Reading Score": [avg_reading_score],
                                    "% Passing Math": [percent_passed_math],
                                    "% Passing Reading": [percent_passed_reading],
                                    "% Overall Passing": [percent_overall_passed]
})
district_summary_df["Total Students"] = district_summary_df["Total Students"].astype(int).map("{:,}".format)
district_summary_df["Total Budget"] = district_summary_df["Total Budget"].astype(float).map("${:,.2f}".format)

district_summary_df
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
school_group = school_data_complete_df.groupby(["school_name"])


school_data_extensions = school_data.copy(deep=True) 
students = school_data_extensions["size"]
budget_per_school = school_data_extensions["budget"]
#school_name = school_data["school_name"]
school_data_extensions["budget_per_student"] = school_data_extensions["budget"]/school_data_extensions["size"]


school_math_passing = school_data_complete_df.loc[school_data_complete_df["math_score"] >= 70]
school_group_math=school_math_passing.groupby(["school_name"])
math_count=school_group_math.count()["Student ID"]


#thchool_group.loc[school_group["math_score"] >= 70, "math_score"]).count()/)*100
# percent_passed_reading = ((school_data_complete_df.loc[school_data_complete_df["reading_score"] >= 70, "reading_score"]).count()/total_students)*100           
# first_passed_math = school_data_complete_df.loc[school_data_complete_df["math_score"] >= 70, ["reading_score"]]
# then_passed_reading = (first_passed_math.loc[first_passed_math["reading_score"] >= 70, "reading_score"]).count()
# percent_overall_passed = (then_passed_reading/total_students)*100




avg_math_score_by_school = school_group["math_score"].mean()
avg_reading_score_by_school = school_group["reading_score"].mean()

school_data_extensions.reset_index(drop=True)
school_data_extensions.set_index("school_name", inplace=True)
school_summary_df = pd.DataFrame({"Average Math Score": avg_math_score_by_school,
                               "Average Reading Score": avg_reading_score_by_school,
                                 "math_count": math_count})


new_df=school_data_extensions.merge(school_summary_df, left_index=True, right_index=True)
new_df["% Passing Math"]=(new_df["math_count"]/new_df["size"])*100

new_df
# Out:
#                        School ID      type  size   budget  budget_per_student  \
# school_name
# Huang High School              0  District  2917  1910635               655.0
# Figueroa High School           1  District  2949  1884411               639.0
# Shelton High School            2   Charter  1761  1056600               600.0
# Hernandez High School          3  District  4635  3022020               652.0
# Griffin High School            4   Charter  1468   917500               625.0
# Wilson High School             5   Charter  2283  1319574               578.0
# Cabrera High School            6   Charter  1858  1081356               582.0
# Bailey High School             7  District  4976  3124928               628.0
# Holden High School             8   Charter   427   248087               581.0
# Pena High School               9   Charter   962   585858               609.0
# Wright High School            10   Charter  1800  1049400               583.0
# ...

# %%
school_data_extensions
# Out:
#                        School ID      type  size   budget  budget_per_student
# school_name
# Huang High School              0  District  2917  1910635               655.0
# Figueroa High School           1  District  2949  1884411               639.0
# Shelton High School            2   Charter  1761  1056600               600.0
# Hernandez High School          3  District  4635  3022020               652.0
# Griffin High School            4   Charter  1468   917500               625.0
# Wilson High School             5   Charter  2283  1319574               578.0
# Cabrera High School            6   Charter  1858  1081356               582.0
# Bailey High School             7  District  4976  3124928               628.0
# Holden High School             8   Charter   427   248087               581.0
# Pena High School               9   Charter   962   585858               609.0
# Wright High School            10   Charter  1800  1049400               583.0
# ...

# %%
total_schools = school_data_complete_df["school_name"].unique()
students = school_data_complete_df["school_name"].value_counts()
students
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: school_name, dtype: int64

# %%
school_data
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
school_series = pd.Series ({'Huang High School': ["9th", "10th", "11th", "12th"], 
                          'Figueroa High School': ["9th", "10th", "11th", "12th"], 
                          'Shelton High School': ["9th", "10th", "11th", "12th"],
                          'Hernandez High School': ["9th", "10th", "11th", "12th"], 
                          'Griffin High School':["9th", "10th", "11th", "12th"], 
                          'Wilson High School':["9th", "10th", "11th", "12th"], 
                          'Cabrera High School':["9th", "10th", "11th", "12th"], 
                          'Bailey High School': ["9th", "10th", "11th", "12th"],
                          'Holden High School':["9th", "10th", "11th", "12th"], 
                          'Pena High School':["9th", "10th", "11th", "12th"], 
                          'Wright High School':["9th", "10th", "11th", "12th"], 
                          'Rodriguez High School':["9th", "10th", "11th", "12th"], 
                          'Johnson High School':["9th", "10th", "11th", "12th"], 
                          'Ford High School':["9th", "10th", "11th", "12th"],
                          'Thomas High School':["9th", "10th", "11th", "12th"]})


school_series
# Out:
# Huang High School        [9th, 10th, 11th, 12th]
# Figueroa High School     [9th, 10th, 11th, 12th]
# Shelton High School      [9th, 10th, 11th, 12th]
# Hernandez High School    [9th, 10th, 11th, 12th]
# Griffin High School      [9th, 10th, 11th, 12th]
# Wilson High School       [9th, 10th, 11th, 12th]
# Cabrera High School      [9th, 10th, 11th, 12th]
# Bailey High School       [9th, 10th, 11th, 12th]
# Holden High School       [9th, 10th, 11th, 12th]
# Pena High School         [9th, 10th, 11th, 12th]
# Wright High School       [9th, 10th, 11th, 12th]
# Rodriguez High School    [9th, 10th, 11th, 12th]
# Johnson High School      [9th, 10th, 11th, 12th]
# Ford High School         [9th, 10th, 11th, 12th]
# Thomas High School       [9th, 10th, 11th, 12th]
# dtype: object

# %% [markdown]
# # Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
top_performing_df = school_summary_df.sort_values("% Overall Passing", ascending=False)
top_performing_df.head()

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
bottom_performing_df = school_summary_df.sort_values("% Overall Passing", ascending=True)
bottom_performing_df.head()

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
grade_series = pd.Series(["9th", "10th", "11th", "12th"])

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.

Create a pandas series for each grade. Hint: use a conditional statement.

Group each series by school

Combine the series into a dataframe

Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
max_budget=school_summary_df.loc[school_summary_df["Per Student Budget"]].max()
min_budget=school_summary_df.loc[school_summary_df["Per Student Budget"]].min()
difference = max_budget - min_budget
divided= difference/4

""

bins = [0, 575, 625, 700]
group_names = ["<$550", "$550-600" , "$601-650", "651-700"]

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
bins = [0, 1000, 2000, 5000]
group_names = [small(<1000), Medium (1000-2000)], Large (2001-5000)]

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
